# %%
import pyspan as ps

# %%
import numpy as np

# %%
# EDA 1 ( explratory data analysis)
# Step 1
# Initial Data Exploration
# Step 2
# Data Cleaning
# Step 3
# Data Visualization

# %%
import pandas as pd

# %%
path = '/content/Sales Report.xlsx'
df=pd.read_excel(path)
pd.set_option('display.max_columns', None)
df.head(5)
# Out:
#        Unnamed: 0           Unnamed: 1           Unnamed: 2 Unnamed: 3  \
# 0  Sales Database                  NaN                  NaN        NaN
# 1  Year 2018-2020                  NaN                  NaN        NaN
# 2             NaN                  NaN                  NaN        NaN
# 3        Order_ID           Order Date            Ship Date  Ship Mode
# 4         DO-1001  2018-01-03 00:00:00  2018-01-07 00:00:00   Standard
#
#            Unnamed: 4 Unnamed: 5     Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                 NaN        NaN            NaN        NaN        NaN
# 1                 NaN        NaN            NaN        NaN        NaN
# 2                 NaN        NaN            NaN        NaN        NaN
# 3       customer name    Segment        Country   Currency       City
# 4  1231-darren powers          1  United States        USD    Houston
#
#   Unnamed: 9 Unnamed: 10                Unnamed: 11   Unnamed: 12  \
# ...

# %%
pd.set_option('display.max_columns', None)
df.tail(5)
# Out:
# 3    Order_ID           Order Date            Ship Date    Ship Mode  \
# 6685  DO-7678  2020-12-31 00:00:00  2021-01-05 00:00:00     Standard
# 6686  DO-7679  2020-12-31 00:00:00  2021-01-08 00:00:00     Standard
# 6687  DO-7680  2020-12-31 00:00:00  2021-01-08 00:00:00     Standard
# 6688  DO-7681  2020-12-31 00:00:00  2021-01-06 00:00:00     Standard
# 6689  DO-7682  2020-12-31 00:00:00  2021-01-02 00:00:00  First Class
#
# 3      customer name Segment        Country Currency           City  \
# 6685  rian decherney       1  United States      USD        Anaheim
# 6686      emily phan       1  United States      USD   Jacksonville
# 6687      emily phan       1  United States      USD   Jacksonville
# 6688        ecky pak       1  United States      USD  San Francisco
# 6689    duane benoit       1  United States      USD      Lancaster
#
# 3          State Region                   Category Sub-Category  \
# 6685  California   East                electronics       Phones
# ...

# %%
#data cleaning
# 1 deleting unwanted rows
# 2 deleting unwanted column
# 3 Clean up dirty/Garbage data
# 4 Fillup Null cells with NA
# 5 formatting Date Cloumn
# 6 Filling Missing Values in Region Column with appropriate Regions
# 7 Replacing Segment column with company given segments
# 8 change header row
# 9 Deleting empty rows

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order Date', 'Ship Date', 'Ship Mode', 'customer name',
#        'Segment', 'Country', 'Currency', 'City', 'State', 'Region', 'Category',
#        'Sub-Category', 'Product Name', 'Item Price', 'Quantity', 'Cost',
#        'Sales', 'Expense', '% Discount', 'Discount', 'Packaging Cost',
#        'Service and other cost', 'Total Cost', 'Profit'],
#       dtype='object', name=3)

# %%
pd.set_option('display.max_rows', None)
df.isnull().sum()
# Out:
# 3
# Order_ID                  0
# Order Date                0
# Ship Date                 0
# Ship Mode                 0
# customer name             0
# Segment                   0
# Country                   0
# Currency                  0
# City                      0
# State                     0
# Region                    0
# Category                  0
# Sub-Category              0
# Product Name              0
# Item Price                0
# Quantity                  0
# Cost                      0
# Sales                     0
# Expense                   0
# % Discount                0
# Discount                  0
# Packaging Cost            0
# Service and other cost    0
# Total Cost                0
# Profit                    0
# dtype: int64

# %%
df.shape
# Out:
# (6690, 25)

# %%
pip install pyspan

# %%
header_row = 3
df.columns = df.iloc[header_row]
df.head(5)
# Out:
# 7  DO-1004  2018-01-04 00:00:00  2018-01-08 00:00:00  Standard  phillina ober  \
# 4  DO-1001  2018-01-03 00:00:00  2018-01-07 00:00:00  Standard  darren powers
# 5  DO-1002  2018-01-04 00:00:00  2018-01-08 00:00:00  Standard  phillina ober
# 6  DO-1003  2018-01-04 00:00:00  2018-01-08 00:00:00  Standard  phillina ober
# 7  DO-1004  2018-01-04 00:00:00  2018-01-08 00:00:00  Standard  phillina ober
# 9  DO-1005  2018-01-05 00:00:00  2018-01-13 00:00:00  Standard     mick brown
#
# 7  2  United States  USD    Naperville      Illinois  East  \
# 4  1  United States  USD       Houston         Texas  East
# 5  2  United States  USD    Naperville      Illinois  East
# 6  2  United States  USD    Naperville      Illinois  East
# 7  2  United States  USD    Naperville      Illinois  East
# 9  1  United States  USD  Philadelphia  Pennsylvania  East
#
# 7  stationary & office items   Labels  \
# 4  stationary & office items    Paper
# 5  stationary & office items  Binders
# ...

# %%
df = df.drop(df.index[[0, 1, 2, 3]])
df.head(5)
# Out:
# 3 Order_ID           Order Date            Ship Date Ship Mode  \
# 4  DO-1001  2018-01-03 00:00:00  2018-01-07 00:00:00  Standard
# 5  DO-1002  2018-01-04 00:00:00  2018-01-08 00:00:00  Standard
# 6  DO-1003  2018-01-04 00:00:00  2018-01-08 00:00:00  Standard
# 7  DO-1004  2018-01-04 00:00:00  2018-01-08 00:00:00  Standard
# 8      NaN                  NaN                  NaN       NaN
#
# 3       customer name Segment        Country Currency        City     State  \
# 4  1231-darren powers       1  United States      USD     Houston     Texas
# 5  3744-phillina ober       2  United States      USD  Naperville  Illinois
# 6  3744-phillina ober       2  United States      USD  Naperville  Illinois
# 7  3744-phillina ober       2  United States      USD  Naperville  Illinois
# 8                 NaN     NaN            NaN      NaN         NaN       NaN
#
# 3 Region                   Category Sub-Category  \
# 4   East  stationary & office items        Paper
# ...

# %%
null_mask = df.isnull().all(axis=1)
null_rows = df[null_mask]
print(null_rows)
# Out:
# 3  Order_ID Order Date Ship Date Ship Mode customer name Segment Country  \
# 8       NaN        NaN       NaN       NaN           NaN     NaN     NaN
# 25      NaN        NaN       NaN       NaN           NaN     NaN     NaN
# 35      NaN        NaN       NaN       NaN           NaN     NaN     NaN
# 36      NaN        NaN       NaN       NaN           NaN     NaN     NaN
#
# 3  Currency City State Region Category Sub-Category Product Name Item Price  \
# 8       NaN  NaN   NaN    NaN      NaN          NaN          NaN        NaN
# 25      NaN  NaN   NaN    NaN      NaN          NaN          NaN        NaN
# 35      NaN  NaN   NaN    NaN      NaN          NaN          NaN        NaN
# 36      NaN  NaN   NaN    NaN      NaN          NaN          NaN        NaN
#
# 3  Quantity Cost Sales Expense % Discount Discount Packaging Cost  \
# 8       NaN  NaN   NaN     NaN        NaN      NaN            NaN
# 25      NaN  NaN   NaN     NaN        NaN      NaN            NaN
# ...

# %%
df = df.drop(df.index[[4, 21, 31, 32]])

# %%
null_mask = df.isnull().all(axis=1)
null_rows = df[null_mask]
print(null_rows)
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order Date, Ship Date, Ship Mode, customer name, Segment, Country, Currency, City, State, Region, Category, Sub-Category, Product Name, Item Price, Quantity, Cost, Sales, Expense, % Discount, Discount, Packaging Cost, Service and other cost, Total Cost, Profit]
# Index: []

# %%
df.head(10)
# Out:
# 3  Order_ID           Order Date            Ship Date     Ship Mode  \
# 4   DO-1001  2018-01-03 00:00:00  2018-01-07 00:00:00      Standard
# 5   DO-1002  2018-01-04 00:00:00  2018-01-08 00:00:00      Standard
# 6   DO-1003  2018-01-04 00:00:00  2018-01-08 00:00:00      Standard
# 7   DO-1004  2018-01-04 00:00:00  2018-01-08 00:00:00      Standard
# 9   DO-1005  2018-01-05 00:00:00  2018-01-13 00:00:00      Standard
# 10  DO-1006  2018-01-06 00:00:00  2018-01-08 00:00:00  Second Class
# 11  DO-1007  2018-01-06 00:00:00  2018-01-07 00:00:00   First Class
# 12  DO-1008  2018-01-06 00:00:00  2018-01-10 00:00:00      Standard
# 13  DO-1009  2018-01-06 00:00:00  2018-01-10 00:00:00      Standard
# 14  DO-1010  2018-01-06 00:00:00  2018-01-10 00:00:00      Standard
#
# 3           customer name Segment        Country Currency          City  \
# 4      1231-darren powers       1  United States      USD       Houston
# 5      3744-phillina ober       2  United States      USD    Naperville
# ...

# %%
df = ps.handle_nulls(df, columns='Region', action='replace', with_val='East')

# %%
df.head(10)
# Out:
# 3  Order_ID           Order Date            Ship Date     Ship Mode  \
# 4   DO-1001  2018-01-03 00:00:00  2018-01-07 00:00:00      Standard
# 5   DO-1002  2018-01-04 00:00:00  2018-01-08 00:00:00      Standard
# 6   DO-1003  2018-01-04 00:00:00  2018-01-08 00:00:00      Standard
# 7   DO-1004  2018-01-04 00:00:00  2018-01-08 00:00:00      Standard
# 9   DO-1005  2018-01-05 00:00:00  2018-01-13 00:00:00      Standard
# 10  DO-1006  2018-01-06 00:00:00  2018-01-08 00:00:00  Second Class
# 11  DO-1007  2018-01-06 00:00:00  2018-01-07 00:00:00   First Class
# 12  DO-1008  2018-01-06 00:00:00  2018-01-10 00:00:00      Standard
# 13  DO-1009  2018-01-06 00:00:00  2018-01-10 00:00:00      Standard
# 14  DO-1010  2018-01-06 00:00:00  2018-01-10 00:00:00      Standard
#
# 3           customer name Segment        Country Currency          City  \
# 4      1231-darren powers       1  United States      USD       Houston
# 5      3744-phillina ober       2  United States      USD    Naperville
# ...

# %%
df = ps.handle_nulls(df, columns='Region', action='replace', with_val='East')

# %%
df.head(10)
# Out:
# 3  Order_ID           Order Date            Ship Date     Ship Mode  \
# 4   DO-1001  2018-01-03 00:00:00  2018-01-07 00:00:00      Standard
# 5   DO-1002  2018-01-04 00:00:00  2018-01-08 00:00:00      Standard
# 6   DO-1003  2018-01-04 00:00:00  2018-01-08 00:00:00      Standard
# 7   DO-1004  2018-01-04 00:00:00  2018-01-08 00:00:00      Standard
# 9   DO-1005  2018-01-05 00:00:00  2018-01-13 00:00:00      Standard
# 10  DO-1006  2018-01-06 00:00:00  2018-01-08 00:00:00  Second Class
# 11  DO-1007  2018-01-06 00:00:00  2018-01-07 00:00:00   First Class
# 12  DO-1008  2018-01-06 00:00:00  2018-01-10 00:00:00      Standard
# 13  DO-1009  2018-01-06 00:00:00  2018-01-10 00:00:00      Standard
# 14  DO-1010  2018-01-06 00:00:00  2018-01-10 00:00:00      Standard
#
# 3           customer name Segment        Country Currency          City  \
# 4      1231-darren powers       1  United States      USD       Houston
# 5      3744-phillina ober       2  United States      USD    Naperville
# ...

# %%
df['customer name'].head(10)
# Out:
# 4        1231-darren powers
# 5        3744-phillina ober
# 6        3744-phillina ober
# 7        3744-phillina ober
# 9           3310-mick brown
# 10    2971-lycoris saunders
# 11       2107-jack o'briant
# 12       3005-maria etezadi
# 13       3005-maria etezadi
# 14       3005-maria etezadi
# Name: customer name, dtype: object

# %%
df['customer name'] = df['customer name'].str[+5:]

# %%
df['customer name'].head(10)
# Out:
# 4        darren powers
# 5        phillina ober
# 6        phillina ober
# 7        phillina ober
# 9           mick brown
# 10    lycoris saunders
# 11       jack o'briant
# 12       maria etezadi
# 13       maria etezadi
# 14       maria etezadi
# Name: customer name, dtype: object

# %%
df.head(1)
# Out:
# 3 Order_ID           Order Date            Ship Date Ship Mode  customer name  \
# 4  DO-1001  2018-01-03 00:00:00  2018-01-07 00:00:00  Standard  darren powers
#
# 3 Segment        Country Currency     City  State Region  \
# 4       1  United States      USD  Houston  Texas   East
#
# 3                   Category Sub-Category  \
# 4  stationary & office items        Paper
#
# 3                                       Product Name Item Price Quantity Cost  \
# 4  message book, wirebound, four 5 1/2" x 4" form...        247       95  174
#
# 3  Sales Expense % Discount Discount Packaging Cost Service and other cost  \
# 4  23465   16530       0.03   703.95              4                      1
#
# 3 Total Cost    Profit
# 4    6226.05  17238.95
